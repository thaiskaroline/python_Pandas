# %%
import pandas as pd


baseVendas_DF = pd.read_excel(r"C:\\Users\\thais\\Documents\\Udemy - Curso de Python com RPA e Criação de Projetos Reais\Python e Pandas - Análise e Tratamento de Dados\\Planilhas\\Vendas_Merge.xlsx")

baseProdutos_DF = pd.read_excel(r"C:\\Users\\thais\\Documents\\Udemy - Curso de Python com RPA e Criação de Projetos Reais\Python e Pandas - Análise e Tratamento de Dados\\Planilhas\\Produtos_Merge.xlsx")

baseVendedores_DF = pd.read_excel(r"C:\\Users\\thais\\Documents\\Udemy - Curso de Python com RPA e Criação de Projetos Reais\Python e Pandas - Análise e Tratamento de Dados\\Planilhas\\Vendedores_Merge.xlsx")


display(baseVendas_DF)
# Out:
#     Id Vendedor  ID Produto Data Venda  Quantidade Vendida  Valor Unitário  \
# 0         27264      100482 2023-01-01                   8           89.99
# 1         21732      100359 2023-01-02                   2           69.99
# 2         27082      100105 2023-01-03                   2          153.40
# 3         22936      100212 2023-01-04                  10          148.56
# 4         21164      100244 2023-01-05                   6          146.14
# 5         28824      100301 2023-01-06                   2          224.14
# 6         27264      100345 2023-01-07                   4          150.50
# 7         21732      100411 2023-01-08                   4          248.73
# 8         27082      100128 2023-01-09                   9          116.52
# 9         22936      100877 2023-01-10                   1           59.90
# 10        27264      100208 2023-01-11                   6           46.90
# ...

# %%
import pandas as pd


baseVendas_DF = pd.read_excel(r"C:\\Users\\thais\\Documents\\Udemy - Curso de Python com RPA e Criação de Projetos Reais\Python e Pandas - Análise e Tratamento de Dados\\Planilhas\\Vendas_Merge.xlsx")

baseProdutos_DF = pd.read_excel(r"C:\\Users\\thais\\Documents\\Udemy - Curso de Python com RPA e Criação de Projetos Reais\Python e Pandas - Análise e Tratamento de Dados\\Planilhas\\Produtos_Merge.xlsx")

baseVendedores_DF = pd.read_excel(r"C:\\Users\\thais\\Documents\\Udemy - Curso de Python com RPA e Criação de Projetos Reais\Python e Pandas - Análise e Tratamento de Dados\\Planilhas\\Vendedores_Merge.xlsx")

#MERGE= Uniu através de um denominador COMUM
baseVendas_DF = baseVendas_DF.merge(baseVendedores_DF)

display(baseVendas_DF)
# Out:
#     Id Vendedor  ID Produto Data Venda  Quantidade Vendida  Valor Unitário  \
# 0         27264      100482 2023-01-01                   8           89.99
# 1         27264      100345 2023-01-07                   4          150.50
# 2         27264      100208 2023-01-11                   6           46.90
# 3         27264      100244 2023-01-20                   9          146.14
# 4         27264      100345 2023-01-22                   6          150.50
# 5         21732      100359 2023-01-02                   2           69.99
# 6         21732      100411 2023-01-08                   4          248.73
# 7         21732      100226 2023-01-12                   2           41.90
# 8         21732      100001 2023-01-15                   8           89.90
# 9         21732      100105 2023-01-18                   7          153.40
# 10        21732      100411 2023-01-23                   4          248.73
# ...

# %%
import pandas as pd


baseVendas_DF = pd.read_excel(r"C:\\Users\\thais\\Documents\\Udemy - Curso de Python com RPA e Criação de Projetos Reais\Python e Pandas - Análise e Tratamento de Dados\\Planilhas\\Vendas_Merge.xlsx")

baseProdutos_DF = pd.read_excel(r"C:\\Users\\thais\\Documents\\Udemy - Curso de Python com RPA e Criação de Projetos Reais\Python e Pandas - Análise e Tratamento de Dados\\Planilhas\\Produtos_Merge.xlsx")

baseVendedores_DF = pd.read_excel(r"C:\\Users\\thais\\Documents\\Udemy - Curso de Python com RPA e Criação de Projetos Reais\Python e Pandas - Análise e Tratamento de Dados\\Planilhas\\Vendedores_Merge.xlsx")

#MERGE= Uniu através de um denominador COMUM
baseVendas_DF = baseVendas_DF.merge(baseProdutos_DF)

display(baseVendas_DF)
# Out:
#     Id Vendedor  ID Produto Data Venda  Quantidade Vendida  Valor Unitário  \
# 0         27264      100482 2023-01-01                   8           89.99
# 1         37579      100482 2023-01-16                   4           89.99
# 2         21732      100359 2023-01-02                   2           69.99
# 3         20437      100359 2023-01-17                   7           69.99
# 4         27082      100105 2023-01-03                   2          153.40
# 5         21732      100105 2023-01-18                   7          153.40
# 6         22936      100212 2023-01-04                  10          148.56
# 7         27082      100212 2023-01-19                   7          148.56
# 8         21164      100244 2023-01-05                   6          146.14
# 9         27264      100244 2023-01-20                   9          146.14
# 10        28824      100301 2023-01-06                   2          224.14
# ...

# %%
import pandas as pd


baseVendas_DF = pd.read_excel(r"C:\\Users\\thais\\Documents\\Udemy - Curso de Python com RPA e Criação de Projetos Reais\Python e Pandas - Análise e Tratamento de Dados\\Planilhas\\Vendas_Merge.xlsx")

baseProdutos_DF = pd.read_excel(r"C:\\Users\\thais\\Documents\\Udemy - Curso de Python com RPA e Criação de Projetos Reais\Python e Pandas - Análise e Tratamento de Dados\\Planilhas\\Produtos_Merge.xlsx")

baseVendedores_DF = pd.read_excel(r"C:\\Users\\thais\\Documents\\Udemy - Curso de Python com RPA e Criação de Projetos Reais\Python e Pandas - Análise e Tratamento de Dados\\Planilhas\\Vendedores_Merge.xlsx")

#MERGE= Uniu através de um denominador COMUM
baseVendas_DF = baseVendas_DF.merge(baseProdutos_DF)

baseVendas_DF = baseVendas_DF.merge(baseVendedores_DF)

display(baseVendas_DF)
# Out:
#     Id Vendedor  ID Produto Data Venda  Quantidade Vendida  Valor Unitário  \
# 0         27264      100482 2023-01-01                   8           89.99
# 1         27264      100244 2023-01-20                   9          146.14
# 2         27264      100345 2023-01-07                   4          150.50
# 3         27264      100345 2023-01-22                   6          150.50
# 4         27264      100208 2023-01-11                   6           46.90
# 5         37579      100482 2023-01-16                   4           89.99
# 6         21732      100359 2023-01-02                   2           69.99
# 7         21732      100105 2023-01-18                   7          153.40
# 8         21732      100411 2023-01-08                   4          248.73
# 9         21732      100411 2023-01-23                   4          248.73
# 10        21732      100208 2023-01-26                   5           46.90
# ...

# %%
import pandas as pd


baseVendas_DF = pd.read_excel(r"C:\\Users\\thais\\Documents\\Udemy - Curso de Python com RPA e Criação de Projetos Reais\Python e Pandas - Análise e Tratamento de Dados\\Planilhas\\Vendas_Merge.xlsx")

baseProdutos_DF = pd.read_excel(r"C:\\Users\\thais\\Documents\\Udemy - Curso de Python com RPA e Criação de Projetos Reais\Python e Pandas - Análise e Tratamento de Dados\\Planilhas\\Produtos_Merge.xlsx")

baseVendedores_DF = pd.read_excel(r"C:\\Users\\thais\\Documents\\Udemy - Curso de Python com RPA e Criação de Projetos Reais\Python e Pandas - Análise e Tratamento de Dados\\Planilhas\\Vendedores_Merge.xlsx")

#MERGE= Uniu através de um denominador COMUM
baseVendas_DF = baseVendas_DF.merge(baseProdutos_DF)

baseVendas_DF = baseVendas_DF.merge(baseVendedores_DF)


resumoDF = baseVendas_DF[["Vendedor","Produto","Total Vendas"]]
display(resumoDF)
# Out:
#             Vendedor                        Produto  Total Vendas
# 0   Leonardo Almeida                 Tênis Feminino        719.92
# 1   Leonardo Almeida  Camisa Masculina Festa Balada       1315.26
# 2   Leonardo Almeida        Jaqueta Masculina Preta        602.00
# 3   Leonardo Almeida        Jaqueta Masculina Preta        903.00
# 4   Leonardo Almeida                Calça Bailarina        281.40
# 5       Angela Maria                 Tênis Feminino        359.96
# 6     Eliane Moreira          Calça Feminina Jogger        139.98
# 7     Eliane Moreira               Camisa Masculina       1073.80
# 8     Eliane Moreira              Bolsa de Trabalho        994.92
# 9     Eliane Moreira              Bolsa de Trabalho        994.92
# 10    Eliane Moreira                Calça Bailarina        234.50
# 11    Eliane Moreira                 Camisa Térmica         83.80
# 12    Eliane Moreira                 Colar Pingente        719.20
# ...
